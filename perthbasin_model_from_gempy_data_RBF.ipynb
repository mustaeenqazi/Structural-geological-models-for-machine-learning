# %%
# %matplotlib inline

# %%
from LoopStructural import GeologicalModel
from LoopStructural.visualisation import LavaVuModelViewer
from LoopStructural.datasets import load_claudius #demo data

import pandas as pd
import glob
import numpy as np

# %%
data = pd.read_excel(r'C:\Users\ASUS\Desktop\loopstructural\data perthbasin\perthbasin.xlsx')

# %%
data = data.rename(columns={'azimuth': 'strike', 'formation': 'feature_name'})

# %%
print(data)
# Out:
#                  X             Y            Z  val      strike       dip  \
# 0    393936.142320  6.693633e+06   957.702303    1  263.276747  1.193492
# 1    396918.892567  6.693984e+06   977.204803    1   83.276747  0.349367
# 2    351487.758871  6.688629e+06 -7385.646697    1   83.277000  6.546000
# 3    338518.168564  6.650709e+06 -4542.306605    1  256.590252  1.789915
# 4    397464.032464  6.663078e+06   959.378895    1  268.100891  1.432093
# ..             ...           ...          ...  ...         ...       ...
# 119  353033.649500  6.688811e+06 -5424.239697    5         NaN       NaN
# 120  341942.065600  6.651525e+06 -4152.902105    5         NaN       NaN
# 121  342823.407600  6.651735e+06 -4152.902105    5         NaN       NaN
# 122  337375.397500  6.650011e+06 -1199.239105    5         NaN       NaN
# 123  338177.661300  6.650617e+06 -1227.176105    5         NaN       NaN
#
#      polarity feature_name
# 0         1.0      Permian
# 1         1.0      Permian
# 2         1.0      Permian
# 3         1.0      Permian
# 4         1.0      Permian
# ..        ...          ...
# 119       NaN      Eneabba
# 120       NaN      Eneabba
# 121       NaN      Eneabba
# 122       NaN      Eneabba
# 123       NaN      Eneabba
#
# [124 rows x 8 columns]

# %%
data_claudius, bb_claudius = load_claudius()

# %%
print(bb_claudius)

# %%
###extent_of_model = np.array([[ 340944.288072, 6637386.,  -7357.485252],
 ###[ 393936.142320,  6693633.,   957.702303]])
    
extent_of_model= np.array([[337000,6640000,-18000],
[400000,6710000,1000]])

##[337000, 400000, 6640000, 6710000, -18000, 1000],

# %%
model = GeologicalModel(extent_of_model[0,:],extent_of_model[1,:])

# %%
data['feature_name'].unique()

viewer = LavaVuModelViewer(background='white')
viewer.add_value_data(data[~np.isnan(data['val'])][['X','Y','Z']],data[~np.isnan(data['val'])]['val'],name='value points')
viewer.add_vector_data(data[~np.isnan(data['dip'])][['X','Y','Z']],
                       data[~np.isnan(data['strike'])][['X','Y','Z']],name='orientation points')
viewer.rotate([-85.18760681152344, 42.93233871459961, 0.8641873002052307])
viewer.display()
# Out:
# 2021-09-20 12:35:07,096 ~ LoopStructural.visualisation.model_visualisation ~ ERROR      ~ Plot area has not been defined.
# 2021-09-20 12:35:07,096 ~ LoopStructural.visualisation.model_visualisation ~ ERROR      ~ Plot area has not been defined.
# 2021-09-20 12:35:07,096 ~ LoopStructural.visualisation.model_visualisation ~ ERROR      ~ Plot area has not been defined.
# <img src='data:image/png;base64,...'>

# %%
model.set_model_data(data)



formation_Permian = model.create_and_add_foliation('Permian',
                              interpolatortype='surfe',
                               nelements=1e4,
                               solver='pyamg',method='Laujaunie'
                              )



formation_Coomallo = model.create_and_add_foliation('Coomallo',
                              interpolatortype='surfe',
                               nelements=1e4,
                               solver='pyamg',method='Laujaunie'
                              )




formation_Cretaceous   =    model.create_and_add_foliation('Cretaceous',
                              interpolatortype='surfe',
                               nelements=1e4,
                               solver='pyamg',method='Laujaunie'
                              )



formation_Yarragadee  =    model.create_and_add_foliation('Yarragadee',
                              interpolatortype='surfe',
                               nelements=1e4,
                               solver='pyamg',method='Laujaunie'
                              )



formation_Lesueur   =     model.create_and_add_foliation('Lesueur',
                              interpolatortype='surfe',
                               nelements=1e4,
                               solver='pyamg',method='Laujaunie'
                              )



formation_Eneabba   =   model.create_and_add_foliation('Eneabba',
                              interpolatortype='surfe',
                               nelements=1e4,
                               solver='pyamg',method='Laujaunie'
                              )

# %%
viewer = LavaVuModelViewer(model)


viewer.add_isosurface(formation_Permian,
#                       nslices=5
                     colour = 'blue'
                     ) ##slices=[2,1.5,1],



viewer.add_isosurface(formation_Coomallo,
#                       nslices=5
                      colour = 'green'
                     )


viewer.add_isosurface(formation_Cretaceous,
#                       nslices=5
                      colour = 'red'
                     )


viewer.add_isosurface(formation_Yarragadee,
#                       nslices=5
                   colour = 'yellow'
                  )


viewer.add_isosurface(formation_Lesueur,
#                       nslices=5
                      colour = 'brown'
                     )



viewer.add_isosurface(formation_Eneabba,
#                       nslices=5
                      
                     paint_with=formation_Eneabba)








viewer.rotate([-85.18760681152344, -42.93233871459961, 0.8641873002052307])
viewer.display()
# Out:
# 2021-09-20 12:35:28,302 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Cannot isosurface Eneabba at 0.0, skipping
# 2021-09-20 12:35:28,302 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Cannot isosurface Eneabba at 0.0, skipping
# 2021-09-20 12:35:28,302 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Cannot isosurface Eneabba at 0.0, skipping
# No surface found at the given iso value.
# <img src='data:image/png;base64,...'>

# %%
displacement = 10

model.set_model_data(data)



formation_Permian = model.create_and_add_foliation('Permian',
                              interpolatortype='surfe',
                               nelements=1e4,
                               solver='pyamg',method='Laujaunie'
                              )



formation_Coomallo = model.create_and_add_foliation('Coomallo',
                              interpolatortype='surfe',
                               nelements=1e4,
                               solver='pyamg',method='Laujaunie'
                              )




formation_Cretaceous   =    model.create_and_add_foliation('Cretaceous',
                              interpolatortype='surfe',
                               nelements=1e4,
                               solver='pyamg',method='Laujaunie'
                              )



formation_Yarragadee  =    model.create_and_add_foliation('Yarragadee',
                              interpolatortype='surfe',
                               nelements=1e4,
                               solver='pyamg',method='Laujaunie'
                              )



formation_Lesueur   =     model.create_and_add_foliation('Lesueur',
                              interpolatortype='surfe',
                               nelements=1e4,
                               solver='pyamg',method='Laujaunie'
                              )



formation_Eneabba   =   model.create_and_add_foliation('Eneabba',
                              interpolatortype='surfe',
                               nelements=1e4,
                               solver='pyamg',method='Laujaunie'
                              )


fault_Darling = model.create_and_add_fault('Darling',
                                                  displacement,
                              interpolatortype='surfe',
                               nelements=1e4,
                               steps=4,
                            buffer=0.3
                              )

fault_Hypo_fault_E = model.create_and_add_fault('Hypo_fault_E',
                                                       displacement,
                              interpolatortype='surfe',
                               nelements=1e4,
                                steps=4,
                            buffer=0.3
                              )


fault_Hypo_fault_W = model.create_and_add_fault('Hypo_fault_W',displacement,
                              interpolatortype='surfe',
                               nelements=1e4,
                               steps=4,
                            buffer=0.3
                              )

fault_Urella_North = model.create_and_add_fault('Urella_North',displacement,
                              interpolatortype='surfe',
                               nelements=1e4,
                               solver='pyamg'
                              )

fault_Urella_South = model.create_and_add_fault('Urella_South',displacement,
                              interpolatortype='surfe',
                               nelements=1e4,
                               solver='pyamg'
                              )                 
                            
                              
fault_Abrolhos_Transfer = model.create_and_add_fault('Abrolhos_Transfer',displacement,
                              interpolatortype='surfe',
                               nelements=1e4,
                               solver='pyamg'
                              )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-a13a50c40795> in <module>
#      58                                nelements=1e4,
#      59                                steps=4,
# ---> 60                             buffer=0.3,method='Laujaunie'
#      61                               )
#      62
#
# ~\AppData\Local\conda\conda\envs\tf\lib\site-packages\LoopStructural\modelling\core\geological_model.py in create_and_add_fault(self, fault_surface_data, displacement, fault_slip_vector, fault_center, fault_extent, fault_influence, fault_vectical_radius, faultfunction, **kwargs)
#    1143                                                      name=fault_surface_data,
#    1144                                                      model=self,
# -> 1145                                                      **kwargs)
#    1146         # add data
#    1147         fault_frame_data = self.data[ self.data['feature_name'] == fault_surface_data].copy()
#
# ~\AppData\Local\conda\conda\envs\tf\lib\site-packages\LoopStructural\modelling\fault\fault_builder.py in __init__(self, interpolator, interpolators, model, fault_bounding_box_buffer, **kwargs)
#      19         """
#      20
# ---> 21         StructuralFrameBuilder.__init__(self,interpolator,interpolators,**kwargs)
#      22         self.origin = np.array([np.nan,np.nan,np.nan])
#      23         self.maximum = np.array([np.nan,np.nan,np.nan])
#
# ~\AppData\Local\conda\conda\envs\tf\lib\site-packages\LoopStructural\modelling\features\structural_frame_builder.py in __init__(self, interpolator, interpolators, **kwargs)
#      52                 interpolators = []
#      53                 interpolators.append(interpolator)
# ---> 54                 interpolators.append(interpolator.copy())
#      55                 interpolators.append(interpolator.copy())
#      56             else:
#
# AttributeError: 'SurfeRBFInterpolator' object has no attribute 'copy'

# %%
viewer.add_isosurface(fault_Darling,
                      slices=[0,-60,-250,-330],
                     paint_with=fault_Darling)

viewer.add_isosurface(fault_Hypo_fault_E,
                      slices=[0,-60,-250,-330],
                     paint_with=fault_Hypo_fault_E)

viewer.add_isosurface(fault_Hypo_fault_W,
                      slices=[0,-60,-250,-330],
                     paint_with=fault_Hypo_fault_W)

viewer.add_isosurface(fault_Urella_North ,
                      slices=[0,-60,-250,-330],
                     paint_with=fault_Urella_North )

viewer.add_isosurface(fault_Urella_South,
                      slices=[0,-60,-250,-330],
                     paint_with=fault_Urella_South)

viewer.add_isosurface(fault_Abrolhos_Transfer,
                      slices=[0,-60,-250,-330],
                     paint_with=fault_Abrolhos_Transfer)

# %%
viewer.rotate([-120.18760681152344, -80.93233871459961, 0.8641873002052307])
viewer.display()
# Out:
# <img src='data:image/png;base64,...'>
