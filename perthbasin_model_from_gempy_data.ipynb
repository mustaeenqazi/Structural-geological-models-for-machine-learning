# %%
# %matplotlib inline

# %%
from LoopStructural import GeologicalModel
from LoopStructural.visualisation import LavaVuModelViewer
from LoopStructural.datasets import load_claudius #demo data

import pandas as pd
import glob
import numpy as np

# %%
data = pd.read_excel(r'C:\Users\ASUS\Desktop\loopstructural\data perthbasin\perthbasin.xlsx')

# %%
data = data.rename(columns={'azimuth': 'strike', 'formation': 'feature_name'})

# %%
print(data)
# Out:
#                  X             Y            Z      strike       dip  polarity  \
# 0    393936.142320  6.693633e+06   957.702303  263.276747  1.193492       1.0
# 1    396918.892567  6.693984e+06   977.204803   83.276747  0.349367       1.0
# 2    351487.758871  6.688629e+06 -7385.646697   83.277000  6.546000       1.0
# 3    338518.168564  6.650709e+06 -4542.306605  256.590252  1.789915       1.0
# 4    397464.032464  6.663078e+06   959.378895  268.100891  1.432093       1.0
# ..             ...           ...          ...         ...       ...       ...
# 119  353033.649500  6.688811e+06 -5424.239697         NaN       NaN       NaN
# 120  341942.065600  6.651525e+06 -4152.902105         NaN       NaN       NaN
# 121  342823.407600  6.651735e+06 -4152.902105         NaN       NaN       NaN
# 122  337375.397500  6.650011e+06 -1199.239105         NaN       NaN       NaN
# 123  338177.661300  6.650617e+06 -1227.176105         NaN       NaN       NaN
#
#     feature_name
# 0        Permian
# 1        Permian
# 2        Permian
# 3        Permian
# 4        Permian
# ..           ...
# 119      Eneabba
# 120      Eneabba
# 121      Eneabba
# 122      Eneabba
# 123      Eneabba
#
# [124 rows x 7 columns]

# %%
data_claudius, bb_claudius = load_claudius()

# %%
print(bb_claudius)
# Out:
# [[ 548800. 7816600.  -11010.]
#  [ 552500. 7822000.   -8400.]]

# %%
##extent_of_model = np.array([[ 340944.288072, 6637386.,  -7357.485252],
## [ 393936.142320,  6693633.,   957.702303]])

extent_of_model= np.array([[337000,6640000,-18000],  ##taken from extent of model in gempy
[400000,6710000,1000]])

# %%
print(extent_of_model[0,:])
# Out:
# [ 337000 6640000  -18000]

# %%
print(extent_of_model[1,:])
# Out:
# [ 400000 6710000    1000]

# %%
model = GeologicalModel(extent_of_model[0,:],extent_of_model[1,:])

# %%
data['feature_name'].unique()

viewer = LavaVuModelViewer(background='white')
#viewer.add_value_data(data[~np.isnan(data['X','Y','Z']),['val'],
#name='value points')
viewer.add_vector_data(data[~np.isnan(data['dip'])][['X','Y','Z']],
                       data[~np.isnan(data['strike'])][['X','Y','Z']],name='orientation points')
viewer.rotate([-85.18760681152344, 42.93233871459961, 0.8641873002052307])
viewer.display()
# Out:
# 2021-09-12 12:49:34,245 ~ LoopStructural.visualisation.model_visualisation ~ ERROR      ~ Plot area has not been defined.
# 2021-09-12 12:49:34,245 ~ LoopStructural.visualisation.model_visualisation ~ ERROR      ~ Plot area has not been defined.
# 2021-09-12 12:49:34,245 ~ LoopStructural.visualisation.model_visualisation ~ ERROR      ~ Plot area has not been defined.
# <img src='data:image/png;base64,...'>

# %%
model.set_model_data(data)

formation_Permian = model.create_and_add_foliation('Permian',
                              interpolatortype='PLI',
                               nelements=1e4,
                               solver='pyamg'
                              )
uc = model.add_unconformity(formation_Permian,1)


formation_Coomallo = model.create_and_add_foliation('Coomallo',
                              interpolatortype='PLI',
                               nelements=1e4,
                               solver='pyamg'
                              )





formation_Cretaceous   =    model.create_and_add_foliation('Cretaceous',
                              interpolatortype='PLI',
                               nelements=1e4,
                               solver='pyamg'
                              )



formation_Yarragadee  =    model.create_and_add_foliation('Yarragadee',
                              interpolatortype='PLI',
                               nelements=1e4,
                               solver='pyamg'
                              )



formation_Lesueur   =     model.create_and_add_foliation('Lesueur',
                              interpolatortype='PLI',
                               nelements=1e4,
                               solver='pyamg'
                              )



formation_Eneabba   =   model.create_and_add_foliation('Eneabba',
                              interpolatortype='PLI',
                               nelements=1e4,
                               solver='pyamg'
                              )



fault_Darling = model.create_and_add_foliation('Darling',
                              interpolatortype='PLI',
                               nelements=1e4,
                               solver='pyamg'
                              )

fault_Hypo_fault_E = model.create_and_add_foliation('Hypo_fault_E',
                              interpolatortype='PLI',
                               nelements=1e4,
                               solver='pyamg'
                              )


fault_Hypo_fault_W = model.create_and_add_foliation('Hypo_fault_W',
                              interpolatortype='PLI',
                               nelements=1e4,
                               solver='pyamg'
                              )

fault_Urella_North = model.create_and_add_foliation('Urella_North',
                              interpolatortype='PLI',
                               nelements=1e4,
                               solver='pyamg'
                              )

fault_Urella_South = model.create_and_add_foliation('Urella_South',
                              interpolatortype='PLI',
                               nelements=1e4,
                               solver='pyamg'
                              )
fault_Abrolhos_Transfer = model.create_and_add_foliation('Abrolhos_Transfer',
                              interpolatortype='PLI',
                               nelements=1e4,
                               solver='pyamg'
                              )

# %%
stratigraphic_column = {}
stratigraphic_column['Permian'] = {}
stratigraphic_column['Permian']['unit1'] = {'min':1,'max':10,'id':0}

stratigraphic_column['Coomallo'] = {}
stratigraphic_column['Coomallo']['unit2'] = {'min':-60,'max':0,'id':1}
stratigraphic_column['Coomallo']['unit3'] = {'min':-250,'max':-60,'id':2}
stratigraphic_column['Coomallo']['unit4'] = {'min':-330,'max':-250,'id':3}
stratigraphic_column['Coomallo']['unit5'] = {'min':-360,'max':-330,'id':4}

stratigraphic_column['Woodada_Kockatea'] = {}
stratigraphic_column['Coomallo']['unit6'] = {'min':-400,'max':-360,'id':5}
stratigraphic_column['Coomallo']['unit7'] = {'min':-450,'max':-400,'id':6}

stratigraphic_column['Cretaceous'] = {}
stratigraphic_column['Cretaceous']['unit8'] = {'min':-490,'max':-450,'id':7}
stratigraphic_column['Cretaceous']['unit9'] = {'min':-520,'max':-490,'id':8}

stratigraphic_column['Yarragadee'] = {}
stratigraphic_column['Yarragadee']['unit10'] = {'min':-560,'max':-520,'id':9}
stratigraphic_column['Yarragadee']['unit11'] = {'min':-np.inf,'max':-560,'id':10}

# %%
viewer = LavaVuModelViewer(model)
viewer.add_isosurface(formation_Permian,
#                       nslices=5
                      slices=[0,-60,-250,-330],
                     paint_with=formation_Permian) ##slices=[2,1.5,1],


viewer.add_isosurface(formation_Coomallo,
#                       nslices=5
                      slices=[0,-60,-250,-330],
                     paint_with=formation_Coomallo)


viewer.add_isosurface(formation_Cretaceous,
#                       nslices=5
                      slices=[0,-60,-250,-330],
                     paint_with=formation_Cretaceous)


viewer.add_isosurface(formation_Yarragadee,
#                       nslices=5
                      slices=[0,-60,-250,-330],
                     paint_with=formation_Yarragadee)


viewer.add_isosurface(formation_Lesueur,
#                       nslices=5
                      slices=[0,-60,-250,-330],
                     paint_with=formation_Lesueur)



viewer.add_isosurface(formation_Eneabba,
#                       nslices=5
                      slices=[0,-60,-250,-330],
                     paint_with=formation_Eneabba)


viewer.add_isosurface(fault_Darling,
                      slices=[0,-60,-250,-330],
                     paint_with=fault_Darling)

viewer.add_isosurface(fault_Hypo_fault_E,
                      slices=[0,-60,-250,-330],
                     paint_with=fault_Hypo_fault_E)

viewer.add_isosurface(fault_Hypo_fault_W,
                      slices=[0,-60,-250,-330],
                     paint_with=fault_Hypo_fault_W)

viewer.add_isosurface(fault_Urella_North ,
                      slices=[0,-60,-250,-330],
                     paint_with=fault_Urella_North )

viewer.add_isosurface(fault_Urella_South,
                      slices=[0,-60,-250,-330],
                     paint_with=fault_Urella_South)

viewer.add_isosurface(fault_Abrolhos_Transfer,
                      slices=[0,-60,-250,-330],
                     paint_with=fault_Abrolhos_Transfer)

viewer.rotate([-85.18760681152344, -42.93233871459961, 0.8641873002052307])
viewer.display()
# Out:
# 2021-09-14 00:01:26,009 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:26,009 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:26,009 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:26,015 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:26,015 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:26,015 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:26,020 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:26,020 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:26,020 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:27,302 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:27,302 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:27,302 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:27,311 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:27,311 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:27,311 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:27,320 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:27,320 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:27,320 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:28,582 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:28,582 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:28,582 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:28,590 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:28,590 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:28,590 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:28,596 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:28,596 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:28,596 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:29,780 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:29,780 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:29,780 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:29,795 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:29,795 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:29,795 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:29,800 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:29,800 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:29,800 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:30,830 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:30,830 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:30,830 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:30,841 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:30,841 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:30,841 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:30,850 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:30,850 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:30,850 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:31,983 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Cannot isosurface Eneabba at 0, skipping
# 2021-09-14 00:01:31,983 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Cannot isosurface Eneabba at 0, skipping
# 2021-09-14 00:01:31,983 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Cannot isosurface Eneabba at 0, skipping
# 2021-09-14 00:01:31,989 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:31,989 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:31,989 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:31,997 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:31,997 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:31,997 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:32,004 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:32,004 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:32,004 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# No surface found at the given iso value.
# 2021-09-14 00:01:32,636 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-14 00:01:32,636 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-14 00:01:38,056 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:38,056 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:38,056 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:38,069 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:38,069 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:38,069 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:38,076 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:38,076 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:38,076 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:38,629 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-14 00:01:38,629 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-14 00:01:42,870 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:42,870 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:42,870 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:42,873 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:42,873 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:42,873 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:42,879 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:42,879 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:42,879 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:43,425 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-14 00:01:43,425 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-14 00:01:47,766 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:47,766 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:47,766 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:47,782 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:47,782 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:47,782 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:47,789 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:47,789 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:47,789 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:48,366 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-14 00:01:48,366 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-14 00:01:53,549 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:53,549 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:53,549 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:53,556 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:53,556 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:53,556 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:53,561 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:53,561 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:53,561 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:54,112 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-14 00:01:54,112 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-14 00:01:59,824 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:59,824 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:59,824 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:59,832 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:59,832 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:59,832 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:59,838 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:59,838 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:01:59,838 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:02:00,421 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-14 00:02:00,421 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-14 00:02:01,756 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:02:01,756 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:02:01,756 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:02:01,766 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:02:01,766 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:02:01,766 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:02:01,771 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:02:01,771 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-14 00:02:01,771 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# <img src='data:image/png;base64,...'>

# %%
viewer.rotate([-175.18760681152344, -42.93233871459961, -0.8641873002052307])
viewer.display()
# Out:
# <img src='data:image/png;base64,...'>

# %%
viewer.rotate([85.18760681152344, -42.93233871459961, -0.8641873002052307])
viewer.display()
# Out:
# <img src='data:image/png;base64,...'>

# %%
model.set_stratigraphic_column(stratigraphic_column)

viewer = LavaVuModelViewer(model)
viewer.add_model(cmap='tab20')
viewer.rotate([85.18760681152344, -42.93233871459961, -0.8641873002052307])
viewer.display()
# Out:
# <img src='data:image/png;base64,...'>

# %%
viewer.rotate([-85.18760681152344, -42.93233871459961, -0.8641873002052307])
viewer.display()
# Out:
# <img src='data:image/png;base64,...'>

# %%
viewer = LavaVuModelViewer(model)
viewer.add_model_surfaces(cmap='tab20')
viewer.rotate([-85.18760681152344, -42.93233871459961, -0.8641873002052307])
viewer.display()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# 2021-09-12 13:12:23,121 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:23,121 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:23,121 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:23,990 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:23,990 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:23,990 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:23,990 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:23,990 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:23,990 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:24,001 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:24,001 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:24,001 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:24,008 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:24,008 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:24,008 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:24,016 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:24,016 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:24,016 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:24,025 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:24,025 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:24,025 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:25,836 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:25,836 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:25,836 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:25,842 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:25,842 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:25,842 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:26,758 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:26,758 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:26,758 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:26,762 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:26,762 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-12 13:12:26,762 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# Adding surfaces took 4.350285053253174 seconds
# <img src='data:image/png;base64,...'>
