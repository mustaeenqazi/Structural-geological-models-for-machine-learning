# %%
# %matplotlib inline

# %%
from LoopStructural import GeologicalModel
from LoopStructural.visualisation import LavaVuModelViewer
from LoopStructural.datasets import load_claudius #demo data

import pandas as pd
import glob
import numpy as np

# %%
data = pd.read_excel(r'C:\Users\ASUS\Desktop\loopstructural\data perthbasin\perthbasin.xlsx')

# %%
data = data.rename(columns={'azimuth': 'strike', 'formation': 'feature_name'})

# %%
print(data)
# Out:
#                 X             Y             Z      strike       dip  polarity  \
# 0    3.939361e+05  6.693633e+06  9.577023e+02  263.276747  1.193492       1.0
# 1    3.969189e+05  6.693984e+06  9.772048e+02   83.276747  0.349367       1.0
# 2    3.514878e+05  6.688629e+06 -7.385647e+03   83.277000  6.546000       1.0
# 3    3.385182e+05  6.650709e+06 -4.542307e+03  256.590252  1.789915       1.0
# 4    3.974640e+05  6.663078e+06  9.593789e+02  268.100891  1.432093       1.0
# ..            ...           ...           ...         ...       ...       ...
# 119  3.530336e+11  6.688811e+12 -5.424240e+09         NaN       NaN       NaN
# 120  3.419421e+11  6.651525e+12 -4.152902e+09         NaN       NaN       NaN
# 121  3.428234e+11  6.651735e+12 -4.152902e+09         NaN       NaN       NaN
# 122  3.373754e+11  6.650011e+12 -1.199239e+09         NaN       NaN       NaN
# 123  3.381777e+11  6.650617e+12 -1.227176e+09         NaN       NaN       NaN
#
#     feature_name
# 0        Permian
# 1        Permian
# 2        Permian
# 3        Permian
# 4        Permian
# ..           ...
# 119      Eneabba
# 120      Eneabba
# 121      Eneabba
# 122      Eneabba
# 123      Eneabba
#
# [124 rows x 7 columns]

# %%
data_claudius, bb_claudius = load_claudius()

# %%
print(bb_claudius)
# Out:
# [[ 548800. 7816600.  -11010.]
#  [ 552500. 7822000.   -8400.]]

# %%
###extent_of_model = np.array([[ 340944.288072, 6637386.,  -7357.485252],
 ###[ 393936.142320,  6693633.,   957.702303]])
    
extent_of_model= np.array([[345000,6640000,-8000],
[395000,6690000,100]])

##[337000, 400000, 6640000, 6710000, -18000, 1000],

# %%
model = GeologicalModel(extent_of_model[0,:],extent_of_model[1,:])

# %%
data['feature_name'].unique()

viewer = LavaVuModelViewer(background='white')
##viewer.add_value_data(data[~np.isnan(data['val'])][['X','Y','Z']],data[~np.isnan(data['val'])]['val'],name='value points')
viewer.add_vector_data(data[~np.isnan(data['dip'])][['X','Y','Z']],
                       data[~np.isnan(data['strike'])][['X','Y','Z']],name='orientation points')
viewer.rotate([-85.18760681152344, 42.93233871459961, 0.8641873002052307])
viewer.display()
# Out:
# 2021-09-13 12:45:44,146 ~ LoopStructural.visualisation.model_visualisation ~ ERROR      ~ Plot area has not been defined.
# 2021-09-13 12:45:44,146 ~ LoopStructural.visualisation.model_visualisation ~ ERROR      ~ Plot area has not been defined.
# 2021-09-13 12:45:44,146 ~ LoopStructural.visualisation.model_visualisation ~ ERROR      ~ Plot area has not been defined.
# <img src='data:image/png;base64,...'>

# %%
model.set_model_data(data)



formation_Permian = model.create_and_add_foliation('Permian',
                              interpolatortype='PLI',
                               nelements=1e4,
                               solver='pyamg'
                              )
uc = model.add_unconformity(formation_Permian,1)


formation_Coomallo = model.create_and_add_foliation('Coomallo',
                              interpolatortype='PLI',
                               nelements=1e4,
                               solver='pyamg'
                              )




formation_Cretaceous   =    model.create_and_add_foliation('Cretaceous',
                              interpolatortype='PLI',
                               nelements=1e4,
                               solver='pyamg'
                              )



formation_Yarragadee  =    model.create_and_add_foliation('Yarragadee',
                              interpolatortype='PLI',
                               nelements=1e4,
                               solver='pyamg'
                              )



formation_Lesueur   =     model.create_and_add_foliation('Lesueur',
                              interpolatortype='PLI',
                               nelements=1e4,
                               solver='pyamg'
                              )



formation_Eneabba   =   model.create_and_add_foliation('Eneabba',
                              interpolatortype='PLI',
                               nelements=1e4,
                               solver='pyamg'
                              )

fault_Darling = model.create_and_add_foliation('Darling',
                              interpolatortype='PLI',
                               nelements=1e4,
                               solver='pyamg'
                              )

fault_Hypo_fault_E = model.create_and_add_foliation('Hypo_fault_E',
                              interpolatortype='PLI',
                               nelements=1e4,
                               solver='pyamg'
                              )


fault_Hypo_fault_W = model.create_and_add_foliation('Hypo_fault_W',
                              interpolatortype='PLI',
                               nelements=1e4,
                               solver='pyamg'
                              )

fault_Urella_North = model.create_and_add_foliation('Urella_North',
                              interpolatortype='PLI',
                               nelements=1e4,
                               solver='pyamg'
                              )

fault_Urella_South = model.create_and_add_foliation('Urella_South',
                              interpolatortype='PLI',
                               nelements=1e4,
                               solver='pyamg'
                              )
fault_Abrolhos_Transfer = model.create_and_add_foliation('Abrolhos_Transfer',
                              interpolatortype='PLI',
                               nelements=1e4,
                               solver='pyamg'
                              )

# %%
viewer = LavaVuModelViewer(model)
viewer.add_isosurface(formation_Permian,
#                       nslices=5
                      slices=[0,-60,-250,-330],
                     paint_with=formation_Permian) ##slices=[2,1.5,1],



viewer.add_isosurface(formation_Coomallo,
#                       nslices=5
                      slices=[0,-60,-250,-330],
                     paint_with=formation_Coomallo)


viewer.add_isosurface(formation_Cretaceous,
#                       nslices=5
                      slices=[0,-60,-250,-330],
                     paint_with=formation_Cretaceous)


viewer.add_isosurface(formation_Yarragadee,
#                       nslices=5
                      slices=[0,-60,-250,-330],
                     paint_with=formation_Yarragadee)


viewer.add_isosurface(formation_Lesueur,
#                       nslices=5
                      slices=[0,-60,-250,-330],
                     paint_with=formation_Lesueur)



viewer.add_isosurface(formation_Eneabba,
#                       nslices=5
                      slices=[0,-60,-250,-330],
                     paint_with=formation_Eneabba)







viewer.add_isosurface(fault_Darling,
                      slices=[0,-60,-250,-330],
                     paint_with=fault_Darling)

viewer.add_isosurface(fault_Hypo_fault_E,
                      slices=[0,-60,-250,-330],
                     paint_with=fault_Hypo_fault_E)

viewer.add_isosurface(fault_Hypo_fault_W,
                      slices=[0,-60,-250,-330],
                     paint_with=fault_Hypo_fault_W)

viewer.add_isosurface(fault_Urella_North ,
                      slices=[0,-60,-250,-330],
                     paint_with=fault_Urella_North )

viewer.add_isosurface(fault_Urella_South,
                      slices=[0,-60,-250,-330],
                     paint_with=fault_Urella_South)

viewer.add_isosurface(fault_Abrolhos_Transfer,
                      slices=[0,-60,-250,-330],
                     paint_with=fault_Abrolhos_Transfer)

viewer.rotate([-85.18760681152344, -42.93233871459961, 0.8641873002052307])
viewer.display()
# Out:
# 2021-09-13 12:45:54,956 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Constraints contain nan not adding constraints: norm
# 2021-09-13 12:45:54,956 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Constraints contain nan not adding constraints: norm
# 2021-09-13 12:45:54,999 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-13 12:45:54,999 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-13 12:45:56,165 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:45:56,165 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:45:56,165 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:45:56,179 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:45:56,179 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:45:56,179 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:45:56,192 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:45:56,192 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:45:56,192 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:45:56,807 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-13 12:45:56,807 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-13 12:46:00,068 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:00,068 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:00,068 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:00,068 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:00,068 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:00,068 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:00,090 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:00,090 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:00,090 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:00,646 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-13 12:46:00,646 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-13 12:46:06,725 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:06,725 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:06,725 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:06,740 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:06,740 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:06,740 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:06,749 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:06,749 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:06,749 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:07,281 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-13 12:46:07,281 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-13 12:46:08,725 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:08,725 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:08,725 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:08,740 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:08,740 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:08,740 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:08,747 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:08,747 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:08,747 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:09,418 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-13 12:46:09,418 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-13 12:46:10,476 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:10,476 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:10,476 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:10,476 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:10,476 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:10,476 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:10,488 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:10,488 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:10,488 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:11,023 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-13 12:46:11,023 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-13 12:46:11,039 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ No solution, Eneabba scalar field 0. Add more data.
# 2021-09-13 12:46:11,039 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ No solution, Eneabba scalar field 0. Add more data.
# 2021-09-13 12:46:11,944 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Cannot isosurface Eneabba at 0, skipping
# 2021-09-13 12:46:11,944 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Cannot isosurface Eneabba at 0, skipping
# 2021-09-13 12:46:11,944 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Cannot isosurface Eneabba at 0, skipping
# 2021-09-13 12:46:11,944 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:11,944 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:11,944 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:11,956 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:11,956 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:11,956 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:11,956 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:11,956 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:11,956 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# No surface found at the given iso value.
# 2021-09-13 12:46:12,489 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-13 12:46:12,489 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-13 12:46:16,088 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:16,088 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:16,088 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:16,105 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:16,105 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:16,105 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:16,111 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:16,111 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:16,111 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:16,638 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-13 12:46:16,638 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-13 12:46:19,772 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:19,772 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:19,772 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:19,787 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:19,787 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:19,787 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:19,795 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:19,795 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:19,795 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:20,324 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-13 12:46:20,324 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-13 12:46:24,074 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:24,074 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:24,074 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:24,074 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:24,074 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:24,074 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:24,074 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:24,074 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:24,074 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:24,622 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-13 12:46:24,622 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-13 12:46:28,527 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:28,527 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:28,527 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:28,552 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:28,552 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:28,552 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:28,563 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:28,563 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:28,563 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:29,091 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-13 12:46:29,091 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-13 12:46:32,381 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:32,381 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:32,381 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:32,385 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:32,385 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:32,385 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:32,393 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:32,393 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:32,393 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:32,905 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Constraints contain nan not adding constraints: norm
# 2021-09-13 12:46:32,905 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Constraints contain nan not adding constraints: norm
# 2021-09-13 12:46:32,950 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-13 12:46:32,950 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-09-13 12:46:32,955 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ No solution, Abrolhos_Transfer scalar field 0. Add more data.
# 2021-09-13 12:46:32,955 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ No solution, Abrolhos_Transfer scalar field 0. Add more data.
# 2021-09-13 12:46:33,564 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Cannot isosurface Abrolhos_Transfer at 0, skipping
# 2021-09-13 12:46:33,564 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Cannot isosurface Abrolhos_Transfer at 0, skipping
# 2021-09-13 12:46:33,564 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Cannot isosurface Abrolhos_Transfer at 0, skipping
# 2021-09-13 12:46:33,583 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:33,583 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:33,583 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:33,587 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:33,587 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:33,587 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:33,592 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:33,592 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-09-13 12:46:33,592 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# No surface found at the given iso value.
# <img src='data:image/png;base64,...'>

# %%
viewer.rotate([-120.18760681152344, -80.93233871459961, 0.8641873002052307])
viewer.display()
# Out:
# <img src='data:image/png;base64,...'>

# %%
viewer.rotate([-120.18760681152344, -100.93233871459961, -0.8641873002052307])
viewer.display()
# Out:
# <img src='data:image/png;base64,...'>
